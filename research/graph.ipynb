# %%
import importlib

from dotenv import load_dotenv; load_dotenv()
from txtai.embeddings import Embeddings

from lib import db
importlib.reload(db)
# Out:
# <module 'lib.db' from '/Users/dennis/dev/kg1/research/lib/db/__init__.py'>

# %%
chunks = db.get_text_node_chunks(limit=10000)
chunks = [c["text"] for c in chunks]

docs = db.get_text_nodes(limit=10000)
docs = [c["text"] for c in docs]

# %%
embeddings = Embeddings({
  "path": "sentence-transformers/all-MiniLM-L6-v2",
  "content": True,
  "functions": [
    {"name": "graph", "function": "graph.attribute"},
  ],
  "expressions": [
      {"name": "category", "expression": "graph(indexid, 'category')"},
      {"name": "topic", "expression": "graph(indexid, 'topic')"},
      {"name": "topicrank", "expression": "graph(indexid, 'topicrank')"}
  ],
  "graph": {
      "limit": 15,
      "minscore": 0.1,
      "topics": {
          "categories": ["Society & Culture", "Science & Mathematics", "Health", "Education & Reference", "Computers & Internet", "Sports",
                         "Business & Finance", "Entertainment & Music", "Family & Relationships", "Politics & Government"]
      }
  }
})

embeddings.index((idx, doc, None) for idx, doc in enumerate(chunks))

# %%
graph = embeddings.graph
len(embeddings.graph.topics)

# %%
list(graph.topics.keys())[:10]

# %%
print(embeddings.search("select text from txtai where topic = 'llms_llm_i_we' and topicrank = 0", 2)[0]["text"])

# %%
for x, topic in enumerate(list(graph.topics.keys())[:5]):
    print(graph.categories[x], topic)

# %%
embeddings.search("select * from txtai where similar('LLM')", 10)

# %%
centrality = graph.centrality()

topics = list(graph.topics.keys())

for uid in list(centrality.keys())[:5]:
    topic = graph.attribute(uid, "topic")
    print(f"{topic} ({topics.index(topic)})")

# %%
import openai
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired, OpenAI

client = openai.OpenAI()
representation_model = OpenAI(client, model="gpt-4o", chat=True)

#topic_model = BERTopic(representation_model=representation_model)
topic_model = BERTopic(representation_model=KeyBERTInspired())
topics, probs = topic_model.fit_transform(chunks)

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1   2364                      -1_text_models_attention_llms
# 1        0    493                0_developer_frontend_devops_backend
# 2        1    218              1_python_interpreter_syntax_wtfpython
# 3        2    172             2_causal_causality_causation_inference
# 4        3    157                   3_utterance_faux_tests_knowledge
# ..     ...    ...                                                ...
# 212    211     11               211_layers_residuals_residual_neural
# 213    212     11               212_writers_emacs_shellmaker_toolkit
# 214    213     11             213_notebooklms_notebooklm_notebook_ai
# 215    214     10  214_autochain_autochainchainchain_autochainmod...
# 216    215     10  215_tensor2_tensorreshape2_tensor_tensortodevi...
#
#                                         Representation  \
# 0    [text, models, attention, llms, llm, model, se...
# 1    [developer, frontend, devops, backend, dev, no...
# 2    [python, interpreter, syntax, wtfpython, opera...
# 3    [causal, causality, causation, inference, obse...
# 4    [utterance, faux, tests, knowledge, comprehens...
# ..                                                 ...
# 212  [layers, residuals, residual, neural, normaliz...
# 213  [writers, emacs, shellmaker, toolkit, adventur...
# 214  [notebooklms, notebooklm, notebook, ai, brains...
# 215  [autochain, autochainchainchain, autochainmode...
# 216  [tensor2, tensorreshape2, tensor, tensortodevi...
#
#                                    Representative_Docs
# 0    [Pretty simple, right?\nWe’ll start at the las...
# 1    [- Node.js\n- React\n- Firebase\n- GraphQL\nJa...
# 2    [False\n>>> WTF() is WTF() # identities are al...
# 3    [Given these challenges, how do we combine cau...
# 4    [To manipulate the likelihood that the speaker...
# ..                                                 ...
# 212  [There are two ways to place layer normalizati...
# 213  [74 | 90 | 2022 | $ rm Important.txt (uh oh) |...
# 214  [NotebookLM: an AI notebook for everyone\nNote...
# 215  [If you have experience with LangChain, you al...
# 216  [!pip install -qqq torchtyping hypothesis pyte...
#
# [217 rows x 5 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('developer', 0.56650937),
#  ('frontend', 0.510833),
#  ('devops', 0.50750554),
#  ('backend', 0.48928258),
#  ('dev', 0.4727406),
#  ('nodejs', 0.43792847),
#  ('github', 0.4359008),
#  ('wordpress', 0.40875238),
#  ('web', 0.40300047),
#  ('development', 0.40279642)]

# %%
topic_model.get_document_info(chunks)
# Out:
#                                                Document  Topic  \
# 0     LSP-AI is an open source language server that ...     -1
# 1     - VS Code\n- NeoVim\n- Emacs\n- Helix\n- Subli...    140
# 2     tl;dr LSP-AI abstracts complex implementation ...    140
# 3     LSP-AI aims to fill this gap by providing a la...     -1
# 4     -\nSimplified Plugin Development:\n- LSP-AI ab...    140
# ...                                                 ...    ...
# 9995  Swyx: Stand-in. [00:59:09]\nGeorge: Well, no, ...     25
# 9996  George: maybe the Elon style way of thinking a...     -1
# 9997  have. Right, so I don't need to put, you know,...      5
# 9998  Swyx: In terms of merging, like, isn't it, sho...     25
# 9999  George: It's not that different, right? You re...     79
#
#                                           Name  \
# 0                -1_text_models_attention_llms
# 1     140_editor_editors_backend_collaborative
# 2     140_editor_editors_backend_collaborative
# 3                -1_text_models_attention_llms
# 4     140_editor_editors_backend_collaborative
# ...                                        ...
# 9995                   25_uber_swyx_api_george
# 9996             -1_text_models_attention_llms
# 9997                 5_ai_opensource_cloud_ibm
# 9998                   25_uber_swyx_api_george
# 9999    79_brains_cognition_brain_neuroscience
#
#                                          Representation  \
# 0     [text, models, attention, llms, llm, model, se...
# 1     [editor, editors, backend, collaborative, coll...
# 2     [editor, editors, backend, collaborative, coll...
# 3     [text, models, attention, llms, llm, model, se...
# 4     [editor, editors, backend, collaborative, coll...
# ...                                                 ...
# 9995  [uber, swyx, api, george, just, scam, like, li...
# 9996  [text, models, attention, llms, llm, model, se...
# 9997  [ai, opensource, cloud, ibm, ibms, developers,...
# 9998  [uber, swyx, api, george, just, scam, like, li...
# 9999  [brains, cognition, brain, neuroscience, neuro...
#
#                                     Representative_Docs  \
# 0     [Pretty simple, right?\nWe’ll start at the las...
# 1     [Google Docs, or whatever you need. It&#x27;s ...
# 2     [Google Docs, or whatever you need. It&#x27;s ...
# 3     [Pretty simple, right?\nWe’ll start at the las...
# 4     [Google Docs, or whatever you need. It&#x27;s ...
# ...                                                 ...
# 9995  [Swyx: it's a scam. [00:39:49]\nGeorge: If the...
# 9996  [Pretty simple, right?\nWe’ll start at the las...
# 9997  [I’m now of the opinion that this is the time ...
# 9998  [Swyx: it's a scam. [00:39:49]\nGeorge: If the...
# 9999  [In a study published today in Nature Machine ...
#
#                                             Top_n_words  Probability  \
# 0     text - models - attention - llms - llm - model...     0.000000
# 1     editor - editors - backend - collaborative - c...     0.797016
# 2     editor - editors - backend - collaborative - c...     0.848727
# 3     text - models - attention - llms - llm - model...     0.000000
# 4     editor - editors - backend - collaborative - c...     0.875554
# ...                                                 ...          ...
# 9995  uber - swyx - api - george - just - scam - lik...     1.000000
# 9996  text - models - attention - llms - llm - model...     0.000000
# 9997  ai - opensource - cloud - ibm - ibms - develop...     0.709685
# 9998  uber - swyx - api - george - just - scam - lik...     0.231928
# 9999  brains - cognition - brain - neuroscience - ne...     1.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 9995                    False
# 9996                    False
# 9997                    False
# 9998                    False
# 9999                    False
#
# [10000 rows x 8 columns]

# %%
topic_model.visualize_topics(top_n_topics=100)

# %%
similar_topics, similarity = topic_model.find_topics("llm", top_n=5)

# %%
topic_model.get_topic(similar_topics[0])
# Out:
# [('chess', 0.4384939),
#  ('intentions', 0.41864693),
#  ('llms', 0.38681805),
#  ('llm', 0.36714536),
#  ('conversation', 0.3384717),
#  ('intentionality', 0.30149746),
#  ('act', 0.27352434),
#  ('speech', 0.25560164),
#  ('play', 0.25285593),
#  ('interpret', 0.24501204)]
